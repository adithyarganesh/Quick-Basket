# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("OMG.csv", dtype = str)

# %%
df.head()
# Out:
#   Unnamed: 0                                       product_name  product_id  \
# 0          0  Purple Sequin Tiny Dancer Tutu Ballet Dance Fa...  0000037214
# 1          1                         Ballet Dress-Up Fairy Tutu  0000031887
# 2          2  SHINING IMAGE HUGE PINK LEATHER JEWELRY BOX / ...  0123456479
# 3          3  RiZ Women's Beautify Crafted &frac12; Rimmed F...  0456844570
# 4          4  Lantin White Visor Wrap Around Ski Style Aviat...  0456808574
#
#       rank               category          item_price  \
# 0  1233557               Clothing              440.37
# 1     8547  Sports &amp; Outdoors              427.77
# 2    16987       Kitchen & Dining  4093.7400000000002
# 3  1180499               Clothing                 NaN
# 4  1038084               Clothing                 NaN
#
#                                          also_viewed  \
# 0           'B00JO8II76', 'B00DGN4R1Q', 'B00E1YRI4C'
# 1  'B00E1YRI4C', 'B00D23MC6W', 'B00AFDOPDA', 'B00...
# ...

# %%
df = df.drop(["Unnamed: 0"],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1503384 entries, 0 to 1503383
# Data columns (total 8 columns):
# product_name       1502696 non-null object
# product_id         1503384 non-null object
# rank               1421649 non-null object
# category           1421649 non-null object
# item_price         574882 non-null object
# also_viewed        1001533 non-null object
# bought_together    646136 non-null object
# also_bought        444130 non-null object
# dtypes: object(8)
# memory usage: 91.8+ MB

# %%
# cols = [c for c in df.row if c != 'Clothing']

# %%
row = df[df.rows.drop(list(df.filter(regex='Clothing')))]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-90-74ea0ab65b2a> in <module>()
# ----> 1 row = df[df.rows.drop(list(df.filter(regex='Clothing')))]
#
# C:\Users\Adithya\Anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
row = df[df['category'].isin(['Clothing'])]
import random
rand = df["item_price"].fillna(np.random.randn()**2)

# %%
rand.head()
# Out:
# 0                440.37
# 1                427.77
# 2    4093.7400000000002
# 3              0.697622
# 4              0.697622
# Name: item_price, dtype: object

# %%
# rand["dd"] = np.random.randn(len(X[np.isnan(X)]))

# %%
# rand["item_price"].max()
rand = rand.to_frame().astype(float)

# %%
rand.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1503384 entries, 0 to 1503383
# Data columns (total 1 columns):
# item_price    1503384 non-null float64
# dtypes: float64(1)
# memory usage: 11.5 MB

# %%
# row["price"] = rand["item_price"]

# %%
row.head()
# Out:
#                                         product_name  product_id     rank  \
# 0  Purple Sequin Tiny Dancer Tutu Ballet Dance Fa...  0000037214  1233557
# 3  RiZ Women's Beautify Crafted &frac12; Rimmed F...  0456844570  1180499
# 4  Lantin White Visor Wrap Around Ski Style Aviat...  0456808574  1038084
# 7  Max-MPH Black - Large Wayfarer Sunglasses Avai...  0456840532  2728771
# 8  FX1 Small Adult Aviator Sunglasses with Silver...  0456787283   456854
#
#    category item_price                                        also_viewed  \
# 0  Clothing     440.37           'B00JO8II76', 'B00DGN4R1Q', 'B00E1YRI4C'
# 3  Clothing        NaN  'B008MTRT1O', 'B00BUG47S4', 'B00GTVY0DC', 'B00...
# 4  Clothing        NaN  'B00A6JD8EA', 'B00BFL4FTA', 'B00JPI9AAO', 'B00...
# 7  Clothing        NaN  'B001K9DPPC', 'B00BV9MU2K', 'B0042FHTDK', 'B00...
# 8  Clothing        NaN  'B00AIPLH22', 'B005P1H8KO', 'B00CMCVKC6', 'B00...
#
#   bought_together also_bought
# 0             NaN         NaN
# ...

# %%
row = row.drop(["category"],axis=1).sort_values("rank")

# %%
df.loc[df['rank'] == '2']
# Out:
#                                               product_name  product_id rank  \
# 25362                     Sanuk Women's Yoga Mat Flip Flop  B000DZUGOM    2
# 25371                     Sanuk Women's Yoga Mat Flip Flop  B000DZZFLG    2
# 25372                     Sanuk Women's Yoga Mat Flip Flop  B000DZZFL6    2
# 25374                     Sanuk Women's Yoga Mat Flip Flop  B000DZZFUW    2
# 25376                     Sanuk Women's Yoga Mat Flip Flop  B000DZZFLQ    2
# 762180   Alex and Ani &quot;Bangle Bar&quot; Birthstone...  B007UMDB0C    2
# 762188   Alex and Ani &quot;Bangle Bar&quot; Birthstone...  B007UMDB7U    2
# 762192   Alex and Ani &quot;Bangle Bar&quot; Birthstone...  B007UMDB02    2
# 762194   Alex and Ani &quot;Bangle Bar&quot; Birthstone...  B007UMDBNY    2
# 762195   Alex and Ani &quot;Bangle Bar&quot; Birthstone...  B007UMDB7A    2
# 762196   Alex and Ani &quot;Bangle Bar&quot; Birthstone...  B007UMDBP2    2
# ...

# %%
row.head()
# Out:
#                                               product_name  product_id rank  \
# 1490553  Generic Disney Frozen Dress Princess Elsa Girl...  B00JL81OWA    1
# 1490574  Generic Disney Frozen Dress Princess Elsa Girl...  B00JL81OUC    1
# 1490559  Generic Disney Frozen Dress Princess Elsa Girl...  B00JL81P38    1
# 1490546  Generic Disney Frozen Dress Princess Elsa Girl...  B00JL81P06    1
# 1000466  Hanes Men's Classics Five-Pack Boxer Brief - C...  B00ACIGVIK   10
#
#         item_price   also_viewed bought_together also_bought
# 1490553        NaN           NaN             NaN         NaN
# 1490574        NaN           NaN             NaN         NaN
# 1490559        NaN           NaN             NaN         NaN
# 1490546        NaN           NaN             NaN         NaN
# 1000466        NaN  'B00KQVADGY'             NaN         NaN

# %%
row.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 657651 entries, 0 to 1503383
# Data columns (total 8 columns):
# product_name       657645 non-null object
# product_id         657651 non-null object
# rank               657651 non-null object
# category           657651 non-null object
# item_price         245333 non-null object
# also_viewed        378218 non-null object
# bought_together    242514 non-null object
# also_bought        167302 non-null object
# dtypes: object(8)
# memory usage: 45.2+ MB

# %%
row.to_csv("just_clothing.csv")

# %%
row['item_price'] = row['item_price'].fillna(0)

# %%
row.head()
# Out:
#                                         product_name  product_id     rank  \
# 0  Purple Sequin Tiny Dancer Tutu Ballet Dance Fa...  0000037214  1233557
# 3  RiZ Women's Beautify Crafted &frac12; Rimmed F...  0456844570  1180499
# 4  Lantin White Visor Wrap Around Ski Style Aviat...  0456808574  1038084
# 7  Max-MPH Black - Large Wayfarer Sunglasses Avai...  0456840532  2728771
# 8  FX1 Small Adult Aviator Sunglasses with Silver...  0456787283   456854
#
#    category item_price                                        also_viewed  \
# 0  Clothing     440.37           'B00JO8II76', 'B00DGN4R1Q', 'B00E1YRI4C'
# 3  Clothing          0  'B008MTRT1O', 'B00BUG47S4', 'B00GTVY0DC', 'B00...
# 4  Clothing          0  'B00A6JD8EA', 'B00BFL4FTA', 'B00JPI9AAO', 'B00...
# 7  Clothing          0  'B001K9DPPC', 'B00BV9MU2K', 'B0042FHTDK', 'B00...
# 8  Clothing          0  'B00AIPLH22', 'B005P1H8KO', 'B00CMCVKC6', 'B00...
#
#   bought_together also_bought
# 0             NaN         NaN
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1503384 entries, 0 to 1503383
# Data columns (total 8 columns):
# product_name       1502696 non-null object
# product_id         1503384 non-null object
# rank               1421649 non-null object
# category           1421649 non-null object
# item_price         574882 non-null object
# also_viewed        1001533 non-null object
# bought_together    646136 non-null object
# also_bought        444130 non-null object
# dtypes: object(8)
# memory usage: 91.8+ MB

# %%
row
# Out:
#                                               product_name  product_id  \
# 0        Purple Sequin Tiny Dancer Tutu Ballet Dance Fa...  0000037214
# 3        RiZ Women's Beautify Crafted &frac12; Rimmed F...  0456844570
# 4        Lantin White Visor Wrap Around Ski Style Aviat...  0456808574
# 7        Max-MPH Black - Large Wayfarer Sunglasses Avai...  0456840532
# 8        FX1 Small Adult Aviator Sunglasses with Silver...  0456787283
# 9        Riz Small Unisex (Mens/ Womens) Black Classic ...  0456838384
# 30               Carter's Basic White SLEEVELESS Bodysuits  1412718031
# 32                                  2013 Desk Pad Calendar  1465014578
# 41                Bambino Balls Short Sleeve Tennis Outfit  1608322181
# 42                Bambino Balls Short Sleeve Soccer Outfit  1608322130
# 43       Bambino Balls Short Sleeve Football Outfit Bro...  1608322262
# 75                     La Leela Men's Hawaiian Print Shirt  245600258X
# ...
