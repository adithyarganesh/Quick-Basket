# %%
import pandas as pd
import numpy as np

# %%
cat = pd.read_csv("Categories.csv")

# %%
cat.head()
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked',)).History will not be written to the database.
#    Unnamed: 0                        salesRank
# 0           0            {'Clothing': 1233557}
# 1           1  {'Sports &amp; Outdoors': 8547}
# 2           2      {'Kitchen & Dining': 16987}
# 3           3            {'Clothing': 1180499}
# 4           4            {'Clothing': 1038084}

# %%
cat = cat.drop(["Unnamed: 0"],axis=1)

# %%
a = cat

# %%
a = cat["salesRank"].str.replace('\d+', '')

# %%
b = cat['salesRank'].str.extract('(\d+)')
# Out:
# /home/adithyas/.local/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.

# %%
b.head()
# Out:
# 0    1233557
# 1       8547
# 2      16987
# 3    1180499
# 4    1038084
# Name: salesRank, dtype: object

# %%
cat = a.to_frame()

# %%
cat.head()
# Out:
#                      salesRank
# 0               {'Clothing': }
# 1  {'Sports &amp; Outdoors': }
# 2       {'Kitchen & Dining': }
# 3               {'Clothing': }
# 4               {'Clothing': }

# %%
cat['salesRank'] = cat['salesRank'].map(lambda x: str(x)[2:])

# %%
cat['salesRank'] = cat['salesRank'].map(lambda x: str(x)[2:])
cat['salesRank'] = cat['salesRank'].map(lambda x: str(x)[:-4])

# %%
cat.head()
# Out:
#                salesRank
# 0               Clothing
# 1  Sports &amp; Outdoors
# 2       Kitchen & Dining
# 3               Clothing
# 4               Clothing

# %%
r = b.to_frame()

# %%
r["cat"] = cat["salesRank"]

# %%
r.head()
# Out:
#   salesRank                    cat
# 0   1233557               Clothing
# 1      8547  Sports &amp; Outdoors
# 2     16987       Kitchen & Dining
# 3   1180499               Clothing
# 4   1038084               Clothing

# %%
r.to_csv("rank.csv")

# %%
df = pd.read_csv("Cleaned_data.csv", dtype = str)

# %%
df.head()
# Out:
#   Unnamed: 0                                       product_name  product_id  \
# 0     826936  U.S. Polo Assn. Sport Men's US9061 Watch with ...  B008D902Q2
# 1        583  Converse Unisex Chuck Taylor Classic Colors Sn...  B000072UN4
# 2        591  Converse Unisex Chuck Taylor Classic Colors Sn...  B000072UN1
# 3        594  Converse Unisex Chuck Taylor Classic Colors Sn...  B000072UMJ
# 4     425689  Wholesale Lot of 50Pc 14G Belly Button Navel R...  B004HWZLBA
#
#            item_price                                        also_viewed  \
# 0             1385.37  'B00E955EOO', 'B00DJ242ZK', 'B00AFXL15A', 'B00...
# 1                 NaN                                       'B001IX6F1G'
# 2                 NaN  'B005BMCKVE', 'B0000AS4YH', 'B005BMEJCW', 'B00...
# 3                 NaN  'B000AP4ZZG', 'B000APACVW', 'B008LQR36O', 'B00...
# 4  116.55000000000001  'B00A3S40Z0', 'B00B4022II', 'B00AWP6BGU', 'B00...
#
#                                      bought_together  \
# ...

# %%
new_df = df.sort_values("Unnamed: 0")

# %%
new_df.head()
# Out:
#        Unnamed: 0                                       product_name  \
# 88736           0  Purple Sequin Tiny Dancer Tutu Ballet Dance Fa...
# 874912          1                         Ballet Dress-Up Fairy Tutu
# 942872         10       Red Crocodile Embossed Leather Travel Wallet
# 732290        100  Shungite. Obereg GLAZ GORA Na podveske / Shung...
# 858371       1000                                Batman Utility Belt
#
#         product_id item_price  \
# 88736   0000037214     440.37
# 874912  0000031887     427.77
# 942872  0641674791        NaN
# 732290  5699031936        NaN
# 858371  B000096QJ7        NaN
#
#                                               also_viewed  \
# 88736            'B00JO8II76', 'B00DGN4R1Q', 'B00E1YRI4C'
# 874912  'B00E1YRI4C', 'B00D23MC6W', 'B00AFDOPDA', 'B00...
# 942872  'B00A8OV6R4', 'B00A8P5M96', 'B00A80A9EY', 'B00...
# 732290                                       'B00CCAC2CA'
# 858371  'B000N8S1GE', 'B0072ER5O6', 'B0099DPY6E', 'B00...
#
# ...

# %%
df = pd.read_csv("Amazon product data.csv")

# %%
df
# Out:
#                asin                                            related  \
# 0        0000037214  {'also_viewed': ['B00JO8II76', 'B00DGN4R1Q', '...
# 1        0000031887  {'also_bought': ['0000031852', '0000031895', '...
# 2        0123456479  {'also_bought': ['B000BMTCK6', 'B0006JCGUM', '...
# 3        0456844570  {'also_viewed': ['B008MTRT1O', 'B00BUG47S4', '...
# 4        0456808574  {'also_viewed': ['B00A6JD8EA', 'B00BFL4FTA', '...
# 5        0456830197                    {'also_bought': ['729300236X']}
# 6        0456856293  {'also_viewed': ['B005P1HF2U', 'B006K5JWOE', '...
# 7        0456840532  {'also_viewed': ['B001K9DPPC', 'B00BV9MU2K', '...
# 8        0456787283  {'also_viewed': ['B00AIPLH22', 'B005P1H8KO', '...
# 9        0456838384  {'also_viewed': ['B001K9DPPC', 'B0042FHTDK', '...
# 10       0641674791                                                NaN
# 11       0641997078  {'also_viewed': ['B00A8OV6R4', 'B00A8P5M96', '...
# ...
